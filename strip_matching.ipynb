# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import stripROtools
from stripROtools import colors

#from matplotlib import style
#style.use('dark_background')

# %% [markdown]
# # UH DLC Micromegas

# %%
# Mesh voltage values to include in analysis
UH_DLC_Vmesh = [620,630,640,650,660,670,680,690,700]

# Empty lists to fill with data
UH_DLC_xHyL_mu = []
UH_DLC_xHyL_mu_err = []
UH_DLC_xHyL_sigma = []
UH_DLC_xHyL_sigma_err = []

UH_DLC_xHyH_mu = []
UH_DLC_xHyH_mu_err = []
UH_DLC_xHyH_sigma = []
UH_DLC_xHyH_sigma_err = []

UH_DLC_xLyL_mu = []
UH_DLC_xLyL_mu_err = []
UH_DLC_xLyL_sigma = []
UH_DLC_xLyL_sigma_err = []

UH_DLC_xLyH_mu = []
UH_DLC_xLyH_mu_err = []
UH_DLC_xLyH_sigma = []
UH_DLC_xLyH_sigma_err = []

# %%
for Vmesh in UH_DLC_Vmesh:


    print("--------------------UH DLC Micromegas, Vmesh = ", str(Vmesh),"--------------------")

    # Location of data
    file_loc = ["/Users/majdghrear/data/VMM3a_SRS/AUG23/UH_DLC/Fe55/"+str(Vmesh)+"Vmesh_bc_40p000_tac_60_ccs_4_cs_2_dt_200_mst_1_spc_1500_dp_200_cr_0p00-1000p00_coin_center-of-mass_test.root"]

    # Create pandas data frame of the cluster info
    df_cluster = stripROtools.read_root(file_loc, clusters=True, hits=False)


    # Define additional columns
    df_cluster["nhits"]=df_cluster.apply(lambda row: len(row.strips0)+len(row.strips1) ,axis=1)
    # Calculate time offset based on time difference of max ADC hit in x and y
    df_cluster['maxADC_offset'] = df_cluster.apply(lambda row: row.times0[np.argmax(row.adcs0)] -  row.times1[np.argmax(row.adcs1)] , axis=1)

    # Fiducialize on single VMM in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=10, min_hits=5,map="UH")
    print("High x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xHyL_mu += [mu]
    UH_DLC_xHyL_mu_err += [mu_err]
    UH_DLC_xHyL_sigma += [sigma]
    UH_DLC_xHyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=13, min_hits=5,map="UH")
    print("High x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xHyH_mu += [mu]
    UH_DLC_xHyH_mu_err += [mu_err]
    UH_DLC_xHyH_sigma += [sigma]
    UH_DLC_xHyH_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=10, min_hits=5,map="UH")
    print("Low x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xLyL_mu += [mu]
    UH_DLC_xLyL_mu_err += [mu_err]
    UH_DLC_xLyL_sigma += [sigma]
    UH_DLC_xLyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=13, min_hits=5,map="UH")
    print("Low x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xLyH_mu += [mu]
    UH_DLC_xLyH_mu_err += [mu_err]
    UH_DLC_xLyH_sigma += [sigma]
    UH_DLC_xLyH_sigma_err += [sigma_err]
# Out:
# --------------------UH DLC Micromegas, Vmesh =  620 --------------------
# High x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# High x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  630 --------------------
# High x low y VMM combo
# Mu:  -11.746020199686598 +/- 0.715739567398747
# Sigma:  16.488148280119464 +/- 0.5724819994697815
# High x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  640 --------------------
# High x low y VMM combo
# Mu:  -8.233586323855414 +/- 0.1750824377690765
# ...

# %% [markdown]
# # UH No DLC Micromegas

# %%
# Mesh voltage values to include in analysis
UH_NoDLC_Vmesh = [620,630,640,650,660]

# Empty lists to fill with data
UH_NoDLC_xHyL_mu = []
UH_NoDLC_xHyL_mu_err = []
UH_NoDLC_xHyL_sigma = []
UH_NoDLC_xHyL_sigma_err = []

UH_NoDLC_xHyH_mu = []
UH_NoDLC_xHyH_mu_err = []
UH_NoDLC_xHyH_sigma = []
UH_NoDLC_xHyH_sigma_err = []

UH_NoDLC_xLyL_mu = []
UH_NoDLC_xLyL_mu_err = []
UH_NoDLC_xLyL_sigma = []
UH_NoDLC_xLyL_sigma_err = []

UH_NoDLC_xLyH_mu = []
UH_NoDLC_xLyH_mu_err = []
UH_NoDLC_xLyH_sigma = []
UH_NoDLC_xLyH_sigma_err = []

# %%
for Vmesh in UH_NoDLC_Vmesh:


    print("--------------------UH No DLC Micromegas, Vmesh = ", str(Vmesh),"--------------------")

    # Location of data
    file_loc = ["/Users/majdghrear/data/VMM3a_SRS/AUG23/UH_NoDLC/Fe55/"+str(Vmesh)+"Vmesh_bc_40p000_tac_60_ccs_4_cs_2_dt_200_mst_1_spc_1500_dp_200_cr_0p00-1000p00_coin_center-of-mass_test.root"]

    # Create pandas data frame of the cluster info
    df_cluster = stripROtools.read_root(file_loc, clusters=True, hits=False)


    # Define additional columns
    df_cluster["nhits"]=df_cluster.apply(lambda row: len(row.strips0)+len(row.strips1) ,axis=1)
    # Calculate time offset based on time difference of max ADC hit in x and y
    df_cluster['maxADC_offset'] = df_cluster.apply(lambda row: row.times0[np.argmax(row.adcs0)] -  row.times1[np.argmax(row.adcs1)] , axis=1)
    df_cluster['mean_offset']= df_cluster.apply(lambda row: np.mean(row.times0)-np.mean(row.times1) , axis=1)

    # Fiducialize on single VMM in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=10, min_hits=5,map="UH")
    print("High x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xHyL_mu += [mu]
    UH_NoDLC_xHyL_mu_err += [mu_err]
    UH_NoDLC_xHyL_sigma += [sigma]
    UH_NoDLC_xHyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=13, min_hits=5,map="UH")
    print("High x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xHyH_mu += [mu]
    UH_NoDLC_xHyH_mu_err += [mu_err]
    UH_NoDLC_xHyH_sigma += [sigma]
    UH_NoDLC_xHyH_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=10, min_hits=5,map="UH")
    print("Low x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xLyL_mu += [mu]
    UH_NoDLC_xLyL_mu_err += [mu_err]
    UH_NoDLC_xLyL_sigma += [sigma]
    UH_NoDLC_xLyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=13, min_hits=5,map="UH")
    print("Low x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xLyH_mu += [mu]
    UH_NoDLC_xLyH_mu_err += [mu_err]
    UH_NoDLC_xLyH_sigma += [sigma]
    UH_NoDLC_xLyH_sigma_err += [sigma_err]
# Out:
# --------------------UH No DLC Micromegas, Vmesh =  620 --------------------
# High x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# High x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH No DLC Micromegas, Vmesh =  630 --------------------
# High x low y VMM combo
# Mu:  5.07503092755735 +/- 0.5107697308982371
# Sigma:  19.356700824133654 +/- 0.43983808229714216
# High x high y VMM combo
# Mu:  6.1786482670141005 +/- 1.0508231440626763
# Sigma:  18.31010507101019 +/- 0.9676714758633737
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH No DLC Micromegas, Vmesh =  640 --------------------
# High x low y VMM combo
# ...

# %% [markdown]
# # UoS Detector

# %%
# Mesh voltage values to include in analysis
UoS_Vmesh = [970,980,990,1000]

# Empty lists to fill with data
UoS_xHyL_mu = []
UoS_xHyL_mu_err = []
UoS_xHyL_sigma = []
UoS_xHyL_sigma_err = []

UoS_xHyH_mu = []
UoS_xHyH_mu_err = []
UoS_xHyH_sigma = []
UoS_xHyH_sigma_err = []

UoS_xLyL_mu = []
UoS_xLyL_mu_err = []
UoS_xLyL_sigma = []
UoS_xLyL_sigma_err = []

UoS_xLyH_mu = []
UoS_xLyH_mu_err = []
UoS_xLyH_sigma = []
UoS_xLyH_sigma_err = []

# %%
for Vmesh in UoS_Vmesh:


    print("--------------------UoS Micromegas, Vmesh = ", str(Vmesh),"--------------------")

    # Location of data
    file_loc = ["/Users/majdghrear/data/VMM3a_SRS/AUG23/UoS/Fe55/"+str(Vmesh)+"Vmesh_bc_40p000_tac_60_ccs_4_cs_2_dt_200_mst_1_spc_1500_dp_200_cr_0p00-1000p00_coin_center-of-mass_test.root"]

    # Create pandas data frame of the cluster info
    df_cluster = stripROtools.read_root(file_loc, clusters=True, hits=False)


    # Define additional columns
    df_cluster["nhits"]=df_cluster.apply(lambda row: len(row.strips0)+len(row.strips1) ,axis=1)
    # Calculate time offset based on time difference of max ADC hit in x and y
    df_cluster['maxADC_offset'] = df_cluster.apply(lambda row: row.times0[np.argmax(row.adcs0)] -  row.times1[np.argmax(row.adcs1)] , axis=1)
    df_cluster['mean_offset']= df_cluster.apply(lambda row: np.mean(row.times0)-np.mean(row.times1) , axis=1)

    # Fiducialize on single VMM in x and y
    # Quadrant a is xHyL
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=10, min_hits=5, map = 'UoS')
    print("Quadrant a CrystalBall fit")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UoS_xHyL_mu += [mu]
    UoS_xHyL_mu_err += [mu_err]
    UoS_xHyL_sigma += [sigma]
    UoS_xHyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    # Quadrant b is xHyH
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=12, min_hits=5, map = 'UoS')
    print("Quadrant b CrystalBall fit")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UoS_xHyH_mu += [mu]
    UoS_xHyH_mu_err += [mu_err]
    UoS_xHyH_sigma += [sigma]
    UoS_xHyH_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    # Quadrant c is xLyL
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=3, n_vmm_y=10, min_hits=5, map = 'UoS')
    print("Quadrant c CrystalBall fit")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UoS_xLyL_mu += [mu]
    UoS_xLyL_mu_err += [mu_err]
    UoS_xLyL_sigma += [sigma]
    UoS_xLyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    # Quadrant d is xLyH
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=3, n_vmm_y=12, min_hits=5, map = 'UoS')
    print("Quadrant d CrystalBall fit")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "max_ADC")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UoS_xLyH_mu += [mu]
    UoS_xLyH_mu_err += [mu_err]
    UoS_xLyH_sigma += [sigma]
    UoS_xLyH_sigma_err += [sigma_err]
# Out:
# --------------------UoS Micromegas, Vmesh =  970 --------------------
# Quadrant a CrystalBall fit
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Quadrant b CrystalBall fit
# Mu:  -17.08719642284376 +/- 0.39119898705912104
# Sigma:  15.07471512670912 +/- 0.3212393157616605
# Quadrant c CrystalBall fit
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Quadrant d CrystalBall fit
# Mu:  -17.19870708032202 +/- 0.6848906782051671
# Sigma:  15.121464970582808 +/- 0.6163601565212897
# --------------------UoS Micromegas, Vmesh =  980 --------------------
# Quadrant a CrystalBall fit
# Mu:  -11.650184225384843 +/- 0.32910824185499615
# Sigma:  13.751718253585993 +/- 0.2715040493526203
# Quadrant b CrystalBall fit
# Mu:  -14.994463872272714 +/- 0.09959208611332024
# Sigma:  14.415972864264152 +/- 0.07481812362001365
# Quadrant c CrystalBall fit
# Mu:  -11.954602094357256 +/- 0.48401154617631176
# Sigma:  14.488780320935774 +/- 0.41834590604995225
# ...

# %% [markdown]
# # Make plots for all detectors

# %%
# Plot the mu in all 4 quadrants for UH DLC detector


plt.figure()

plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xLyH_mu),linestyle='None', color = colors['black'], marker = '$d$',label='UH DLC d')
plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xHyH_mu),linestyle='None', color = colors['orange'], marker = '$b$',label='UH DLC b')
plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xLyL_mu),linestyle='None', color = colors['cyan'], marker = '$c$',label="UH DLC c")
plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xHyL_mu),linestyle='None', color = colors['green'], marker = '$a$', label="UH DLC a")

# Find mean values
UH_DLC_xLyH_mu_mu, UH_DLC_xLyH_mu_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyH_mu,UH_DLC_xLyH_mu_err)
plt.axhline(UH_DLC_xLyH_mu_mu,linestyle='--',color = colors['black'])

UH_DLC_xHyH_mu_mu, UH_DLC_xHyH_mu_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyH_mu,UH_DLC_xHyH_mu_err)
plt.axhline(UH_DLC_xHyH_mu_mu,linestyle='--',color = colors['orange'])

UH_DLC_xLyL_mu_mu, UH_DLC_xLyL_mu_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyL_mu,UH_DLC_xLyL_mu_err)
plt.axhline(UH_DLC_xLyL_mu_mu,linestyle='--',color = colors['cyan'])

UH_DLC_xHyL_mu_mu, UH_DLC_xHyL_mu_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyL_mu,UH_DLC_xHyL_mu_err)
plt.axhline(UH_DLC_xHyL_mu_mu,linestyle='--',color = colors['green'])


plt.xlabel("Micromegas Mesh Voltage [V]")
plt.legend()
#plt.yscale("log")
plt.ylabel("Time offset distribution mean [ns]")
plt.ylim((-30,30))
plt.tight_layout()
plt.savefig("./figures/VMM_SM_mu_UHDLC.pdf")


print("---- UH DLC timme offset mu ----")
print("Quadrant a: ", UH_DLC_xHyL_mu_mu , "+/-", UH_DLC_xHyL_mu_mu_err )
print("Quadrant b: ", UH_DLC_xHyH_mu_mu , "+/-", UH_DLC_xHyH_mu_mu_err )
print("Quadrant c: ", UH_DLC_xLyL_mu_mu , "+/-", UH_DLC_xLyL_mu_mu_err )
print("Quadrant d: ", UH_DLC_xLyH_mu_mu , "+/-", UH_DLC_xLyH_mu_mu_err )
# Out:
# ---- UH DLC timme offset mu ----
# Quadrant a:  -6.684140674069912 +/- 0.03171867370502211
# Quadrant b:  -5.208232220254531 +/- 0.034227727474192254
# Quadrant c:  6.752723324946302 +/- 0.03858333264780794
# Quadrant d:  6.852294424138033 +/- 0.058807108559041095

# %%
# Plot the mu in all 4 quadrants for UH NoDLC detector


plt.figure()

plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xLyH_mu),linestyle='None', color = colors['black'], marker = '$d$',label='UH No DLC d')
plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xHyH_mu),linestyle='None', color = colors['orange'], marker = '$b$',label='UH No DLC b')
plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xLyL_mu),linestyle='None', color = colors['cyan'], marker = '$c$',label="UH No DLC c")
plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xHyL_mu),linestyle='None', color = colors['green'], marker = '$a$', label="UH No DLC a")

# Find mean values
UH_NoDLC_xLyH_mu_mu, UH_NoDLC_xLyH_mu_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyH_mu,UH_NoDLC_xLyH_mu_err)
plt.axhline(UH_NoDLC_xLyH_mu_mu,linestyle='--',color = colors['black'])

UH_NoDLC_xHyH_mu_mu, UH_NoDLC_xHyH_mu_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyH_mu,UH_NoDLC_xHyH_mu_err)
plt.axhline(UH_NoDLC_xHyH_mu_mu,linestyle='--',color = colors['orange'])

UH_NoDLC_xLyL_mu_mu, UH_NoDLC_xLyL_mu_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyL_mu,UH_NoDLC_xLyL_mu_err)
plt.axhline(UH_NoDLC_xLyL_mu_mu,linestyle='--',color = colors['cyan'])

UH_NoDLC_xHyL_mu_mu, UH_NoDLC_xHyL_mu_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyL_mu,UH_NoDLC_xHyL_mu_err)
plt.axhline(UH_NoDLC_xHyL_mu_mu,linestyle='--',color = colors['green'])


plt.xlabel("Micromegas Mesh Voltage [V]")
plt.legend()
#plt.yscale("log")
plt.ylabel("Time offset distribution mean [ns]")
plt.ylim((-30,30))
plt.tight_layout()
plt.savefig("./figures/VMM_SM_mu_UHNoDLC.pdf")

print("---- UH NoDLC timme offset mu ----")
print("Quadrant a: ", UH_NoDLC_xHyL_mu_mu , "+/-", UH_NoDLC_xHyL_mu_mu_err )
print("Quadrant b: ", UH_NoDLC_xHyH_mu_mu , "+/-", UH_NoDLC_xHyH_mu_mu_err )
print("Quadrant c: ", UH_NoDLC_xLyL_mu_mu , "+/-", UH_NoDLC_xLyL_mu_mu_err )
print("Quadrant d: ", UH_NoDLC_xLyH_mu_mu , "+/-", UH_NoDLC_xLyH_mu_mu_err )
# Out:
# ---- UH NoDLC timme offset mu ----
# Quadrant a:  5.703479970634444 +/- 0.07558834563782187
# Quadrant b:  5.473109884498942 +/- 0.11411374338860263
# Quadrant c:  25.24177512714174 +/- 0.1891804170095377
# Quadrant d:  20.67484153701445 +/- 0.6989553031844001

# %%
# Plot the mu in all 4 quadrants for UoS detector


plt.figure()

plt.errorbar(UoS_Vmesh,np.array(UoS_xLyH_mu),linestyle='None', color = colors['black'], marker = '$d$',label='UoS d')
plt.errorbar(UoS_Vmesh,np.array(UoS_xHyH_mu),linestyle='None', color = colors['orange'], marker = '$b$',label='UoS b')
plt.errorbar(UoS_Vmesh,np.array(UoS_xLyL_mu),linestyle='None', color = colors['cyan'], marker = '$c$',label="UoS c")
plt.errorbar(UoS_Vmesh,np.array(UoS_xHyL_mu),linestyle='None', color = colors['green'], marker = '$a$', label="UoS a")


UoS_mu_mu, UoS_mu_mu_err = stripROtools.fit_horizontal(UoS_Vmesh+UoS_Vmesh+UoS_Vmesh+UoS_Vmesh, UoS_xLyH_mu+UoS_xHyH_mu+UoS_xLyL_mu+UoS_xHyL_mu, UoS_xLyH_mu_err+UoS_xHyH_mu_err+UoS_xLyL_mu_err+UoS_xHyL_mu_err)
plt.axhline(UoS_mu_mu,linestyle='--',color = colors['black'])


plt.xlabel("Micromegas Mesh Voltage [V]")
plt.legend()
#plt.yscale("log")
plt.ylabel("Time offset distribution mean [ns]")
plt.ylim((-30,30))
plt.tight_layout()
plt.savefig("./figures/VMM_SM_mu_UoS.pdf")

# %%
# Plot the sigma in all 4 quadrants for UH DLC detector


plt.figure()

plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xLyH_sigma),linestyle='None', color = colors['black'], marker = '$d$',label='UH DLC d')
plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xHyH_sigma),linestyle='None', color = colors['orange'], marker = '$b$',label='UH DLC b')
plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xLyL_sigma),linestyle='None', color = colors['cyan'], marker = '$c$',label="UH DLC c")
plt.errorbar(UH_DLC_Vmesh,np.array(UH_DLC_xHyL_sigma),linestyle='None', color = colors['green'], marker = '$a$', label="UH DLC a")

# Find mean values
UH_DLC_xLyH_sigma_mu, UH_DLC_xLyH_sigma_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyH_sigma,UH_DLC_xLyH_sigma_err)
plt.axhline(UH_DLC_xLyH_sigma_mu,linestyle='--',color = colors['black'])

UH_DLC_xHyH_sigma_mu, UH_DLC_xHyH_sigma_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyH_sigma,UH_DLC_xHyH_sigma_err)
plt.axhline(UH_DLC_xHyH_sigma_mu,linestyle='--',color = colors['orange'])

UH_DLC_xLyL_sigma_mu, UH_DLC_xLyL_sigma_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyL_sigma,UH_DLC_xLyL_sigma_err)
plt.axhline(UH_DLC_xLyL_sigma_mu,linestyle='--',color = colors['cyan'])

UH_DLC_xHyL_sigma_mu, UH_DLC_xHyL_sigma_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyL_sigma,UH_DLC_xHyL_sigma_err)
plt.axhline(UH_DLC_xHyL_sigma_mu,linestyle='--',color = colors['green'])


plt.xlabel("Micromegas Mesh Voltage [V]")
plt.legend()
#plt.yscale("log")
plt.ylabel("Time offset distribution sigma [ns]")
plt.ylim((12,22))
plt.tight_layout()
plt.savefig("./figures/VMM_SM_sigma_UHDLC.pdf")

print("---- UH DLC time offset sigma ----")
print("Quadrant a: ", UH_DLC_xHyL_sigma_mu , "+/-", UH_DLC_xHyL_sigma_mu_err )
print("Quadrant b: ", UH_DLC_xHyH_sigma_mu , "+/-", UH_DLC_xHyH_sigma_mu_err )
print("Quadrant c: ", UH_DLC_xLyL_sigma_mu , "+/-", UH_DLC_xLyL_sigma_mu_err )
print("Quadrant d: ", UH_DLC_xLyH_sigma_mu , "+/-", UH_DLC_xLyH_sigma_mu_err )
# Out:
# ---- UH DLC time offset sigma ----
# Quadrant a:  16.382492916847905 +/- 0.02476415073730354
# Quadrant b:  16.305924792694974 +/- 0.02678291388877856
# Quadrant c:  14.113658681914023 +/- 0.03144576106969028
# Quadrant d:  14.800689346093627 +/- 0.04823400714320128

# %%
# Plot the sigma in all 4 quadrants for UH NoDLC detector


plt.figure()

plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xLyH_sigma),linestyle='None', color = colors['black'], marker = '$d$',label='UH No DLC d')
plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xHyH_sigma),linestyle='None', color = colors['orange'], marker = '$b$',label='UH No DLC b')
plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xLyL_sigma),linestyle='None', color = colors['cyan'], marker = '$c$',label="UH No DLC c")
plt.errorbar(UH_NoDLC_Vmesh,np.array(UH_NoDLC_xHyL_sigma),linestyle='None', color = colors['green'], marker = '$a$', label="UH No DLC a")

# Find mean values
UH_NoDLC_xLyH_sigma_mu, UH_NoDLC_xLyH_sigma_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyH_sigma,UH_NoDLC_xLyH_sigma_err)
plt.axhline(UH_NoDLC_xLyH_sigma_mu,linestyle='--',color = colors['black'])

UH_NoDLC_xHyH_sigma_mu, UH_NoDLC_xHyH_sigma_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyH_sigma,UH_NoDLC_xHyH_sigma_err)
plt.axhline(UH_NoDLC_xHyH_sigma_mu,linestyle='--',color = colors['orange'])

UH_NoDLC_xLyL_sigma_mu, UH_NoDLC_xLyL_sigma_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyL_sigma,UH_NoDLC_xLyL_sigma_err)
plt.axhline(UH_NoDLC_xLyL_sigma_mu,linestyle='--',color = colors['cyan'])

UH_NoDLC_xHyL_sigma_mu, UH_NoDLC_xHyL_sigma_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyL_sigma,UH_NoDLC_xHyL_sigma_err)
plt.axhline(UH_NoDLC_xHyL_sigma_mu,linestyle='--',color = colors['green'])


plt.xlabel("Micromegas Mesh Voltage [V]")
plt.legend()
#plt.yscale("log")
plt.ylabel("Time offset distribution sigma [ns]")
plt.ylim((12,22))
plt.tight_layout()
plt.savefig("./figures/VMM_SM_sigma_UHNoDLC.pdf")

print("---- UH NoDLC time offset sigma ----")
print("Quadrant a: ", UH_NoDLC_xHyL_sigma_mu , "+/-", UH_NoDLC_xHyL_sigma_mu_err )
print("Quadrant b: ", UH_NoDLC_xHyH_sigma_mu , "+/-", UH_NoDLC_xHyH_sigma_mu_err )
print("Quadrant c: ", UH_NoDLC_xLyL_sigma_mu , "+/-", UH_NoDLC_xLyL_sigma_mu_err )
print("Quadrant d: ", UH_NoDLC_xLyH_sigma_mu , "+/-", UH_NoDLC_xLyH_sigma_mu_err )
# Out:
# ---- UH NoDLC time offset sigma ----
# Quadrant a:  19.57483316502068 +/- 0.06157328898831164
# Quadrant b:  19.79933673931173 +/- 0.09216921119872926
# Quadrant c:  18.08254721306951 +/- 0.1591420227526062
# Quadrant d:  17.886666823352193 +/- 0.6261674127836139

# %%
# Plot the sigma in all 4 quadrants for UoS detector


plt.figure()

plt.errorbar(UoS_Vmesh,np.array(UoS_xLyH_sigma),linestyle='None', color = colors['black'], marker = '$d$',label='UoS d')
plt.errorbar(UoS_Vmesh,np.array(UoS_xHyH_sigma),linestyle='None', color = colors['orange'], marker = '$b$',label='UoS b')
plt.errorbar(UoS_Vmesh,np.array(UoS_xLyL_sigma),linestyle='None', color = colors['cyan'], marker = '$c$',label="UoS c")
plt.errorbar(UoS_Vmesh,np.array(UoS_xHyL_sigma),linestyle='None', color = colors['green'], marker = '$a$', label="UoS a")


UoS_sigma_mu, UoS_sigma_mu_err = stripROtools.fit_horizontal(UoS_Vmesh+UoS_Vmesh+UoS_Vmesh+UoS_Vmesh, UoS_xLyH_sigma+UoS_xHyH_sigma+UoS_xLyL_sigma+UoS_xHyL_sigma, UoS_xLyH_sigma_err+UoS_xHyH_sigma_err+UoS_xLyL_sigma_err+UoS_xHyL_sigma_err)
plt.axhline(UoS_sigma_mu,linestyle='--',color = colors['black'])

plt.xlabel("Micromegas Mesh Voltage [V]")
plt.legend()
#plt.yscale("log")
plt.ylabel("Time offset distribution sigma [ns]")
plt.ylim((12,22))
plt.tight_layout()
plt.savefig("./figures/VMM_SM_sigma_UoS.pdf")

# %%
# Make and save a time offset distribution database

mydict = {
	'Name' : ["UH DLC a", "UH DLC b", "UH DLC c", "UH DLC d", "UH NoDLC a", "UH NoDLC b", "UH NoDLC c", "UH NoDLC d", "UoS" ],
	'Mu' : [UH_DLC_xHyL_mu_mu,UH_DLC_xHyH_mu_mu,UH_DLC_xLyL_mu_mu,UH_DLC_xLyH_mu_mu,UH_NoDLC_xHyL_mu_mu,UH_NoDLC_xHyH_mu_mu,UH_NoDLC_xLyL_mu_mu,UH_NoDLC_xLyH_mu_mu,UoS_mu_mu],
    'Mu_err' : [UH_DLC_xHyL_mu_mu_err,UH_DLC_xHyH_mu_mu_err,UH_DLC_xLyL_mu_mu_err,UH_DLC_xLyH_mu_mu_err,UH_NoDLC_xHyL_mu_mu_err,UH_NoDLC_xHyH_mu_mu_err,UH_NoDLC_xLyL_mu_mu_err,UH_NoDLC_xLyH_mu_mu_err,UoS_mu_mu_err],
	'Sigma' : [UH_DLC_xHyL_sigma_mu,UH_DLC_xHyH_sigma_mu,UH_DLC_xLyL_sigma_mu,UH_DLC_xLyH_sigma_mu,UH_NoDLC_xHyL_sigma_mu,UH_NoDLC_xHyH_sigma_mu,UH_NoDLC_xLyL_sigma_mu,UH_NoDLC_xLyH_sigma_mu,UoS_sigma_mu],
    'Sigma_err' : [UH_DLC_xHyL_sigma_mu_err,UH_DLC_xHyH_sigma_mu_err,UH_DLC_xLyL_sigma_mu_err,UH_DLC_xLyH_sigma_mu_err,UH_NoDLC_xHyL_sigma_mu_err,UH_NoDLC_xHyH_sigma_mu_err,UH_NoDLC_xLyL_sigma_mu_err,UH_NoDLC_xLyH_sigma_mu_err,UoS_sigma_mu_err]
	}

df = pd.DataFrame(mydict)

df.to_pickle("./data/time_offset.pk")
df
# Out:
#          Name         Mu    Mu_err      Sigma  Sigma_err
# 0    UH DLC a  -6.684141  0.031719  16.382493   0.024764
# 1    UH DLC b  -5.208232  0.034228  16.305925   0.026783
# 2    UH DLC c   6.752723  0.038583  14.113659   0.031446
# 3    UH DLC d   6.852294  0.058807  14.800689   0.048234
# 4  UH NoDLC a   5.703480  0.075588  19.574833   0.061573
# 5  UH NoDLC b   5.473110  0.114114  19.799337   0.092169
# 6  UH NoDLC c  25.241775  0.189180  18.082547   0.159142
# 7  UH NoDLC d  20.674842  0.698955  17.886667   0.626167
# 8         UoS -11.400385  0.026963  15.290716   0.021079

# %% [markdown]
# # Make plots for only the best cahrge sharing quadrant in the UH detectors and the sheffield detector

# %%
f, (ax, ax2) = plt.subplots(1, 2, sharey=True, facecolor='w')

# plot the same data on both axes



ax.errorbar(UH_DLC_Vmesh, np.array(UH_DLC_xHyL_sigma),yerr=UH_DLC_xHyL_sigma_err , linestyle='None', color = colors['green'], marker = 'o', label="UH DLC a")
ax.axhline(UH_DLC_xHyL_sigma_mu,linestyle='--',color = colors['green'])
#ax2.axhline(UH_DLC_xHyL_sigma_mu,linestyle='--',color = colors['green'])


ax.errorbar(UH_NoDLC_Vmesh, np.array(UH_NoDLC_xHyL_sigma),yerr=UH_NoDLC_xHyL_sigma_err , linestyle='None', color = colors['pink'], marker = 'o', label="UH NoDLC a")
ax.axhline(UH_NoDLC_xHyL_sigma_mu,linestyle='--',color = colors['pink'])
#ax2.axhline(UH_NoDLC_xHyL_sigma_mu,linestyle='--',color = colors['pink'])


ax2.errorbar(UoS_Vmesh,np.array(UoS_xLyH_sigma),yerr=UoS_xLyH_sigma_err ,linestyle='None', color = colors['black'], marker = 'o',label='UoS d')
ax2.errorbar(UoS_Vmesh,np.array(UoS_xHyH_sigma),yerr=UoS_xHyH_sigma_err ,linestyle='None', color = colors['orange'], marker = 'o',label='UoS b')
ax2.errorbar(UoS_Vmesh,np.array(UoS_xLyL_sigma),yerr=UoS_xLyL_sigma_err ,linestyle='None', color = colors['cyan'], marker = 'o',label="UoS c")
ax2.errorbar(UoS_Vmesh,np.array(UoS_xHyL_sigma),yerr=UoS_xHyL_sigma_err ,linestyle='None', color = colors['blue'], marker = 'o', label="UoS a")
ax2.axhline(UoS_sigma_mu,linestyle='--',color = colors['black'])
#ax.axhline(UoS_sigma_mu,linestyle='--',color = colors['black'])


ax.set_xlim(620, 710)
ax2.set_xlim(960, 1010)

ax.set_ylim(5, 35)
ax2.set_ylim(5, 35)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)


ax.yaxis.tick_left()
#ax.tick_params(labelright='off')
ax2.yaxis.tick_right()


# This looks pretty good, and was fairly painless, but you can get that
# cut-out diagonal lines look with just a bit more work. The important
# thing to know here is that in axes coordinates, which are always
# between 0-1, spine endpoints are at these locations (0, 0), (0, 1),
# (1, 0), and (1, 1).  Thus, we just need to put the diagonals in the
# appropriate corners of each of our axes, and so long as we use the
# right transform and disable clipping.

d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# What's cool about this is that now if we vary the distance between
# ax and ax2 via f.subplots_adjust(hspace=...) or plt.subplot_tool(),
# the diagonal lines will move accordingly, and stay right at the tips
# of the spines they are 'breaking'

f.legend(ncol=2, fontsize = 15)

f.supxlabel('$V_{Mesh}$ [V]', fontsize = 17)
f.supylabel('$\sigma_{\Delta t}$ [ns]', fontsize = 17)

for ax in f.get_axes():
    ax.tick_params(labelsize=15)

plt.tight_layout()

plt.savefig("./figures/VMM_sigma_delt_t.pdf")

# %%
f, (ax, ax2) = plt.subplots(1, 2, sharey=True, facecolor='w')

# plot the same data on both axes



ax.errorbar(UH_DLC_Vmesh, np.array(UH_DLC_xHyL_mu),yerr=UH_DLC_xHyL_mu_err , linestyle='None', color = colors['green'], marker = 'o', label="UH DLC a")
ax.axhline(UH_DLC_xHyL_mu_mu,linestyle='--',color = colors['green'])
#ax2.axhline(UH_DLC_xHyL_mu_mu,linestyle='--',color = colors['green'])


ax.errorbar(UH_NoDLC_Vmesh, np.array(UH_NoDLC_xHyL_mu),yerr=UH_NoDLC_xHyL_mu_err , linestyle='None', color = colors['pink'], marker = 'o', label="UH NoDLC a")
ax.axhline(UH_NoDLC_xHyL_mu_mu,linestyle='--',color = colors['pink'])
#ax2.axhline(UH_NoDLC_xHyL_mu_mu,linestyle='--',color = colors['pink'])


ax2.errorbar(UoS_Vmesh,np.array(UoS_xLyH_mu),yerr=UoS_xLyH_mu_err ,linestyle='None', color = colors['black'], marker = 'o',label='UoS d')
ax2.errorbar(UoS_Vmesh,np.array(UoS_xHyH_mu),yerr=UoS_xHyH_mu_err ,linestyle='None', color = colors['orange'], marker = 'o',label='UoS b')
ax2.errorbar(UoS_Vmesh,np.array(UoS_xLyL_mu),yerr=UoS_xLyL_mu_err ,linestyle='None', color = colors['cyan'], marker = 'o',label="UoS c")
ax2.errorbar(UoS_Vmesh,np.array(UoS_xHyL_mu),yerr=UoS_xHyL_mu_err ,linestyle='None', color = colors['blue'], marker = 'o', label="UoS a")
ax2.axhline(UoS_mu_mu,linestyle='--',color = colors['black'])
#ax.axhline(UoS_mu_mu,linestyle='--',color = colors['black'])


ax.set_xlim(620, 710)
ax2.set_xlim(960, 1010)

ax.set_ylim(-30, 30)
ax2.set_ylim(-30, 30)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)


ax.yaxis.tick_left()
#ax.tick_params(labelright='off')
ax2.yaxis.tick_right()


# This looks pretty good, and was fairly painless, but you can get that
# cut-out diagonal lines look with just a bit more work. The important
# thing to know here is that in axes coordinates, which are always
# between 0-1, spine endpoints are at these locations (0, 0), (0, 1),
# (1, 0), and (1, 1).  Thus, we just need to put the diagonals in the
# appropriate corners of each of our axes, and so long as we use the
# right transform and disable clipping.

d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (-d, +d), **kwargs)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1-d, 1+d), **kwargs)
ax2.plot((-d, +d), (-d, +d), **kwargs)

# What's cool about this is that now if we vary the distance between
# ax and ax2 via f.subplots_adjust(hspace=...) or plt.subplot_tool(),
# the diagonal lines will move accordingly, and stay right at the tips
# of the spines they are 'breaking'

#f.legend()

f.supxlabel('$V_{Mesh}$ [V]',fontsize=17)
f.supylabel('$\mu_{\Delta t}$ [ns]',fontsize=17)

for ax in f.get_axes():
    ax.tick_params(labelsize=15)

plt.tight_layout()

plt.savefig("./figures/VMM_mu_delt_t.pdf")
