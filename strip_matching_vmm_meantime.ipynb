# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import stripROtools

#from matplotlib import style
#style.use('dark_background')

# %% [markdown]
# # UH DLC Micromegas

# %%
# Mesh voltage values to include in analysis
UH_DLC_Vmesh = [620,630,640,650,660,670,680,690,700]

# Empty lists to fill with data
UH_DLC_xHyL_mu = []
UH_DLC_xHyL_mu_err = []
UH_DLC_xHyL_sigma = []
UH_DLC_xHyL_sigma_err = []

UH_DLC_xHyH_mu = []
UH_DLC_xHyH_mu_err = []
UH_DLC_xHyH_sigma = []
UH_DLC_xHyH_sigma_err = []

UH_DLC_xLyL_mu = []
UH_DLC_xLyL_mu_err = []
UH_DLC_xLyL_sigma = []
UH_DLC_xLyL_sigma_err = []

UH_DLC_xLyH_mu = []
UH_DLC_xLyH_mu_err = []
UH_DLC_xLyH_sigma = []
UH_DLC_xLyH_sigma_err = []

# %%
for Vmesh in UH_DLC_Vmesh:


    print("--------------------UH DLC Micromegas, Vmesh = ", str(Vmesh),"--------------------")

    # Location of data
    file_loc = ["/Users/majdghrear/data/VMM3a_SRS/AUG23/UH_DLC/Fe55/"+str(Vmesh)+"Vmesh_bc_40p000_tac_60_ccs_4_cs_2_dt_200_mst_1_spc_1500_dp_200_cr_0p20-2p00_coin_center-of-mass_test.root"]

    # Create pandas data frame of the cluster info
    df_cluster = stripROtools.read_root(file_loc, clusters=True, hits=False)


    # Define additional columns
    df_cluster["nhits"]=df_cluster.apply(lambda row: len(row.strips0)+len(row.strips1) ,axis=1)
    # Calculate time offset based on time difference of max ADC hit in x and y
    df_cluster['maxADC_offset'] = df_cluster.apply(lambda row: row.times0[np.argmax(row.adcs0)] -  row.times1[np.argmax(row.adcs1)] , axis=1)
    df_cluster['mean_offset']= df_cluster.apply(lambda row: np.mean(row.times0)-np.mean(row.times1) , axis=1)

    # Fiducialize on single VMM in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=10, min_hits=5)
    print("High x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )
    UH_DLC_xHyL_mu += [mu]
    UH_DLC_xHyL_mu_err += [mu_err]
    UH_DLC_xHyL_sigma += [sigma]
    UH_DLC_xHyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=13, min_hits=5)
    print("High x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xHyH_mu += [mu]
    UH_DLC_xHyH_mu_err += [mu_err]
    UH_DLC_xHyH_sigma += [sigma]
    UH_DLC_xHyH_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=10, min_hits=5)
    print("Low x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xLyL_mu += [mu]
    UH_DLC_xLyL_mu_err += [mu_err]
    UH_DLC_xLyL_sigma += [sigma]
    UH_DLC_xLyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=13, min_hits=5)
    print("Low x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_DLC_xLyH_mu += [mu]
    UH_DLC_xLyH_mu_err += [mu_err]
    UH_DLC_xLyH_sigma += [sigma]
    UH_DLC_xLyH_sigma_err += [sigma_err]
# Out:
# --------------------UH DLC Micromegas, Vmesh =  620 --------------------
# High x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# High x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  630 --------------------
# High x low y VMM combo
# Mu:  -16.03305994494608 +/- 0.5901645822732934
# Sigma:  13.588450632246259 +/- 0.521832266929184
# High x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  640 --------------------
# High x low y VMM combo
# Mu:  -12.296854789113972 +/- 0.1397738064140681
# Sigma:  13.943170196664674 +/- 0.10784152373449486
# High x high y VMM combo
# Mu:  -11.023651347453063 +/- 0.24793099754662007
# Sigma:  12.57568584534075 +/- 0.19338889089402644
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  650 --------------------
# High x low y VMM combo
# Mu:  -11.330913960131415 +/- 0.08184533634055939
# Sigma:  13.889125900526706 +/- 0.06394283006260032
# High x high y VMM combo
# Mu:  -11.974734139150225 +/- 0.10913757388584912
# Sigma:  13.00552393488343 +/- 0.08511330335692847
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  660 --------------------
# High x low y VMM combo
# Mu:  -11.57249488292463 +/- 0.06368286036533923
# Sigma:  12.906903523624383 +/- 0.049954339464995424
# High x high y VMM combo
# Mu:  -12.38417041295801 +/- 0.07690523828861605
# Sigma:  13.367370303887725 +/- 0.060021806042953034
# Low x low y VMM combo
# Mu:  -3.0223369181085276 +/- 0.12489344917416388
# Sigma:  -12.266179100549294 +/- 0.09815967507047348
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH DLC Micromegas, Vmesh =  670 --------------------
# High x low y VMM combo
# Mu:  -11.909592326107548 +/- 0.05820509699950655
# Sigma:  12.42948316329761 +/- 0.0455439784984205
# High x high y VMM combo
# Mu:  -12.978234678244021 +/- 0.0653540068893474
# Sigma:  13.106468797923357 +/- 0.05151507509476179
# Low x low y VMM combo
# Mu:  -5.573951456920505 +/- 0.08855850335655346
# Sigma:  13.318788170705902 +/- 0.0711299617564828
# Low x high y VMM combo
# Mu:  -2.891193778061032 +/- 0.3642832916862035
# Sigma:  11.262477000291387 +/- 0.31711815019387385
# --------------------UH DLC Micromegas, Vmesh =  680 --------------------
# High x low y VMM combo
# Mu:  -12.410216881095302 +/- 0.05816134558203968
# Sigma:  12.49845922470586 +/- 0.046102658171228696
# High x high y VMM combo
# Mu:  -13.763737499277704 +/- 0.06297126119224222
# Sigma:  13.217008379904252 +/- 0.050071783969076515
# Low x low y VMM combo
# Mu:  -7.072498651699911 +/- 0.08017986940846895
# Sigma:  13.642219981062116 +/- 0.06350287859325432
# Low x high y VMM combo
# Mu:  -5.547317559586984 +/- 0.31991863537017057
# Sigma:  13.381376437571456 +/- 0.2639232727819398
# --------------------UH DLC Micromegas, Vmesh =  690 --------------------
# High x low y VMM combo
# Mu:  -13.131088311481276 +/- 0.06068098387467219
# Sigma:  13.07933086028474 +/- 0.04829397698115135
# High x high y VMM combo
# Mu:  -14.761962212068198 +/- 0.06288888516603673
# Sigma:  13.384251873183418 +/- 0.049901507091183586
# Low x low y VMM combo
# Mu:  -8.593701885957127 +/- 0.07862685270050274
# Sigma:  13.842816369001687 +/- 0.0607286665113727
# Low x high y VMM combo
# Mu:  -6.406658726078824 +/- 0.2298925768616898
# Sigma:  14.106218286873538 +/- 0.18213108382347884
# --------------------UH DLC Micromegas, Vmesh =  700 --------------------
# High x low y VMM combo
# Mu:  -14.043076747916885 +/- 0.0661761098589545
# Sigma:  14.243535122583626 +/- 0.05306729327470083
# High x high y VMM combo
# Mu:  -16.203578794070822 +/- 0.06672404468245313
# Sigma:  14.198140566891023 +/- 0.05270836074879821
# Low x low y VMM combo
# Mu:  -10.43065233065679 +/- 0.08016749178451738
# Sigma:  14.292831570492076 +/- 0.0615076371419891
# Low x high y VMM combo
# Mu:  -9.882922375777405 +/- 0.17148904693079495
# Sigma:  15.003305591430092 +/- 0.13244106981241047

# %% [markdown]
# # UH No DLC Micromegas

# %%
# Mesh voltage values to include in analysis
UH_NoDLC_Vmesh = [620,630,640,650,660]

# Empty lists to fill with data
UH_NoDLC_xHyL_mu = []
UH_NoDLC_xHyL_mu_err = []
UH_NoDLC_xHyL_sigma = []
UH_NoDLC_xHyL_sigma_err = []

UH_NoDLC_xHyH_mu = []
UH_NoDLC_xHyH_mu_err = []
UH_NoDLC_xHyH_sigma = []
UH_NoDLC_xHyH_sigma_err = []

UH_NoDLC_xLyL_mu = []
UH_NoDLC_xLyL_mu_err = []
UH_NoDLC_xLyL_sigma = []
UH_NoDLC_xLyL_sigma_err = []

UH_NoDLC_xLyH_mu = []
UH_NoDLC_xLyH_mu_err = []
UH_NoDLC_xLyH_sigma = []
UH_NoDLC_xLyH_sigma_err = []

# %%
for Vmesh in UH_NoDLC_Vmesh:


    print("--------------------UH No DLC Micromegas, Vmesh = ", str(Vmesh),"--------------------")

    # Location of data
    file_loc = ["/Users/majdghrear/data/VMM3a_SRS/AUG23/UH_NoDLC/Fe55/"+str(Vmesh)+"Vmesh_bc_40p000_tac_60_ccs_4_cs_2_dt_200_mst_1_spc_1500_dp_200_cr_0p20-2p00_coin_center-of-mass_test.root"]

    # Create pandas data frame of the cluster info
    df_cluster = stripROtools.read_root(file_loc, clusters=True, hits=False)


    # Define additional columns
    df_cluster["nhits"]=df_cluster.apply(lambda row: len(row.strips0)+len(row.strips1) ,axis=1)
    # Calculate time offset based on time difference of max ADC hit in x and y
    df_cluster['maxADC_offset'] = df_cluster.apply(lambda row: row.times0[np.argmax(row.adcs0)] -  row.times1[np.argmax(row.adcs1)] , axis=1)
    df_cluster['mean_offset']= df_cluster.apply(lambda row: np.mean(row.times0)-np.mean(row.times1) , axis=1)

    # Fiducialize on single VMM in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=10, min_hits=5)
    print("High x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xHyL_mu += [mu]
    UH_NoDLC_xHyL_mu_err += [mu_err]
    UH_NoDLC_xHyL_sigma += [sigma]
    UH_NoDLC_xHyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=5, n_vmm_y=13, min_hits=5)
    print("High x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xHyH_mu += [mu]
    UH_NoDLC_xHyH_mu_err += [mu_err]
    UH_NoDLC_xHyH_sigma += [sigma]
    UH_NoDLC_xHyH_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=10, min_hits=5)
    print("Low x low y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xLyL_mu += [mu]
    UH_NoDLC_xLyL_mu_err += [mu_err]
    UH_NoDLC_xLyL_sigma += [sigma]
    UH_NoDLC_xLyL_sigma_err += [sigma_err]

    # Fiducialize on single vmm in x and y
    df_fid = stripROtools.fiducializeVMM(df_cluster, n_vmm_x=2, n_vmm_y=13, min_hits=5)
    print("Low x high y VMM combo")
    mu, mu_err, sigma, sigma_err = stripROtools.fit_offset(df_fid,  method = "mean_time")
    # Print fit results
    print("Mu: ", mu, "+/-", mu_err )
    print("Sigma: ", sigma,"+/-", sigma_err  )

    UH_NoDLC_xLyH_mu += [mu]
    UH_NoDLC_xLyH_mu_err += [mu_err]
    UH_NoDLC_xLyH_sigma += [sigma]
    UH_NoDLC_xLyH_sigma_err += [sigma_err]
# Out:
# --------------------UH No DLC Micromegas, Vmesh =  620 --------------------
# High x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# High x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH No DLC Micromegas, Vmesh =  630 --------------------
# High x low y VMM combo
# Mu:  6.251371884322391 +/- 0.373216924138583
# Sigma:  14.48682508368856 +/- 0.31037882046510795
# High x high y VMM combo
# Mu:  5.395343731223702 +/- 0.7061293513074666
# Sigma:  12.935373216535968 +/- 0.6656625167090535
# Low x low y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH No DLC Micromegas, Vmesh =  640 --------------------
# High x low y VMM combo
# Mu:  6.3598404483737125 +/- 0.1602723248848916
# Sigma:  15.128614663211026 +/- 0.1258502396166723
# High x high y VMM combo
# Mu:  5.506048341766744 +/- 0.27606362333744816
# Sigma:  15.301320580030835 +/- 0.2144355388343236
# Low x low y VMM combo
# Mu:  22.751332484756727 +/- 0.7084334594884986
# Sigma:  13.441258156712037 +/- 0.6723428463639927
# Low x high y VMM combo
# -fit failed-
# Mu:  nan +/- nan
# Sigma:  nan +/- nan
# --------------------UH No DLC Micromegas, Vmesh =  650 --------------------
# /Users/majdghrear/Lab/2DstripRO/stripROtools.py:894: RuntimeWarning: invalid value encountered in sqrt
#   perr = np.sqrt(np.diag(covar))
# High x low y VMM combo
# Mu:  6.766488462015456 +/- 0.09647548587139368
# Sigma:  14.223066271172387 +/- 0.07543601430178223
# High x high y VMM combo
# Mu:  5.820379476194285 +/- 0.1522004201837755
# Sigma:  15.037686258054437 +/- 0.12039241661830248
# Low x low y VMM combo
# Mu:  23.484246671785368 +/- 0.27495932408151313
# Sigma:  13.17096156076407 +/- 0.22682927980563097
# Low x high y VMM combo
# Mu:  19.119907392966205 +/- 1.4755154254636298
# Sigma:  12.458759234384807 +/- 1.54095616517256
# --------------------UH No DLC Micromegas, Vmesh =  660 --------------------
# High x low y VMM combo
# Mu:  6.690083577630622 +/- 0.07754437099563914
# Sigma:  14.112003368225487 +/- 0.06100050241664043
# High x high y VMM combo
# Mu:  5.324533496028077 +/- 0.11386203395157968
# Sigma:  15.081397815969982 +/- 0.09118280520517043
# Low x low y VMM combo
# Mu:  23.698029071421683 +/- 0.17579946491159407
# Sigma:  14.382005468521756 +/- 0.14026103030509277
# Low x high y VMM combo
# Mu:  20.081297131850683 +/- 0.6227327929747478
# Sigma:  14.849509696363613 +/- 0.5425296160430885

# %% [markdown]
# # Make plots for both detectors

# %%
# Plot the mu time offset in all 4 quadrants

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2,figsize=(15,9),sharex='col', sharey='row')

ax1.errorbar(UH_DLC_Vmesh,UH_DLC_xLyH_mu,yerr=UH_DLC_xLyH_mu_err,fmt="*")
DLC_xLyH_mu, DLC_xLyH_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyH_mu,UH_DLC_xLyH_mu_err)
print("DLC xLyH mu = ", DLC_xLyH_mu)
ax1.axhline(DLC_xLyH_mu)
ax1.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xLyH_mu,yerr=UH_NoDLC_xLyH_mu_err,fmt="o")
NoDLC_xLyH_mu, NoDLC_xLyH_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyH_mu,UH_NoDLC_xLyH_mu_err)
print("NoDLC xLyH mu = ", NoDLC_xLyH_mu)
ax1.axhline(NoDLC_xLyH_mu,color='orange')

ax2.errorbar(UH_DLC_Vmesh,UH_DLC_xHyH_mu,yerr=UH_DLC_xHyH_mu_err,fmt="*",label="DLC")
DLC_xHyH_mu, DLC_xHyH_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyH_mu,UH_DLC_xHyH_mu_err)
print("DLC xHyH mu = ", DLC_xHyH_mu)
ax2.axhline(DLC_xHyH_mu)
ax2.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xHyH_mu,yerr=UH_NoDLC_xHyH_mu_err,fmt="o",label="No DLC")
NoDLC_xHyH_mu, NoDLC_xHyH_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyH_mu,UH_NoDLC_xHyH_mu_err)
print("NoDLC xHyH mu = ", NoDLC_xHyH_mu)
ax2.axhline(NoDLC_xHyH_mu,color='orange')
ax2.legend()

ax3.errorbar(UH_DLC_Vmesh,UH_DLC_xLyL_mu,yerr=UH_DLC_xLyL_mu_err,fmt="*")
DLC_xLyL_mu, DLC_xLyL_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyL_mu,UH_DLC_xLyL_mu_err)
print("DLC xLyL mu = ", DLC_xLyL_mu)
ax3.axhline(DLC_xLyL_mu)
ax3.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xLyL_mu,yerr=UH_NoDLC_xLyL_mu_err,fmt="o")
NoDLC_xLyL_mu, NoDLC_xLyL_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyL_mu,UH_NoDLC_xLyL_mu_err)
print("NoDLC xLyL mu = ", NoDLC_xLyL_mu)
ax3.axhline(NoDLC_xLyL_mu,color='orange')

ax4.errorbar(UH_DLC_Vmesh,UH_DLC_xHyL_mu,yerr=UH_DLC_xHyL_mu_err,fmt="*")
DLC_xHyL_mu, DLC_xHyL_mu_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyL_mu,UH_DLC_xHyL_mu_err)
print("DLC xHyL mu = ", DLC_xHyL_mu)
ax4.axhline(DLC_xHyL_mu)
ax4.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xHyL_mu,yerr=UH_NoDLC_xHyL_mu_err,fmt="o")
NoDLC_xHyL_mu, NoDLC_xHyL_mu_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyL_mu,UH_NoDLC_xHyL_mu_err)
print("NoDLC xHyL mu = ", NoDLC_xHyL_mu)
ax4.axhline(NoDLC_xHyL_mu,color='orange')


for ax in fig.get_axes():
    ax.set(xlabel='Mesh voltage [V]', ylabel='$\mu$ [ns]')

for ax in fig.get_axes():
    ax.label_outer()

fig.subplots_adjust(wspace=0, hspace=0)
# Out:
# DLC xLyH mu =  -7.59300266778285
# NoDLC xLyH mu =  19.93594365572388
# DLC xHyH mu =  -13.916589712054382
# NoDLC xHyH mu =  5.5012220245383485
# DLC xLyL mu =  -7.550818406803983
# NoDLC xLyL mu =  23.598945756939234
# DLC xHyL mu =  -12.44771760983076
# NoDLC xHyL mu =  6.665706705318856

# %%
# Plot the sigma time offset in all 4 quadrants

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2,figsize=(15,9),sharex='col', sharey='row')

ax1.errorbar(UH_DLC_Vmesh,UH_DLC_xLyH_sigma,yerr=UH_DLC_xLyH_sigma_err,fmt="*")
DLC_xLyH_sigma, DLC_xLyH_sigma_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyH_sigma,UH_DLC_xLyH_sigma_err)
print("DLC xLyH sigma = ", DLC_xLyH_sigma)
ax1.axhline(DLC_xLyH_sigma)
ax1.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xLyH_sigma,yerr=UH_NoDLC_xLyH_sigma_err,fmt="o")
NoDLC_xLyH_sigma, NoDLC_xLyH_sigma_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyH_sigma,UH_NoDLC_xLyH_sigma_err)
print("NoDLC xLyH sigma = ", NoDLC_xLyH_sigma)
ax1.axhline(NoDLC_xLyH_sigma,color='orange')

ax2.errorbar(UH_DLC_Vmesh,UH_DLC_xHyH_sigma,yerr=UH_DLC_xHyH_sigma_err,fmt="*",label="DLC")
DLC_xHyH_sigma, DLC_xHyH_sigma_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyH_sigma,UH_DLC_xHyH_sigma_err)
print("DLC xHyH sigma = ", DLC_xHyH_sigma)
ax2.axhline(DLC_xHyH_sigma)
ax2.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xHyH_sigma,yerr=UH_NoDLC_xHyH_sigma_err,fmt="o",label="No DLC")
NoDLC_xHyH_sigma, NoDLC_xHyH_sigma_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyH_sigma,UH_NoDLC_xHyH_sigma_err)
print("NoDLC xHyH sigma = ", NoDLC_xHyH_sigma)
ax2.axhline(NoDLC_xHyH_sigma,color='orange')
ax2.legend()

ax3.errorbar(UH_DLC_Vmesh,UH_DLC_xLyL_sigma,yerr=UH_DLC_xLyL_sigma_err,fmt="*")
DLC_xLyL_sigma, DLC_xLyL_sigma_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xLyL_sigma,UH_DLC_xLyL_sigma_err)
print("DLC xLyL sigma = ", DLC_xLyL_sigma)
ax3.axhline(DLC_xLyL_sigma)
ax3.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xLyL_sigma,yerr=UH_NoDLC_xLyL_sigma_err,fmt="o")
NoDLC_xLyL_sigma, NoDLC_xLyL_sigma_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xLyL_sigma,UH_NoDLC_xLyL_sigma_err)
print("NoDLC xLyL sigma = ", NoDLC_xLyL_sigma)
ax3.axhline(NoDLC_xLyL_sigma,color='orange')

ax4.errorbar(UH_DLC_Vmesh,UH_DLC_xHyL_sigma,yerr=UH_DLC_xHyL_sigma_err,fmt="*")
DLC_xHyL_sigma, DLC_xHyL_sigma_err = stripROtools.fit_horizontal(UH_DLC_Vmesh,UH_DLC_xHyL_sigma,UH_DLC_xHyL_sigma_err)
print("DLC xHyL sigma = ", DLC_xHyL_sigma)
ax4.axhline(DLC_xHyL_sigma)
ax4.errorbar(UH_NoDLC_Vmesh,UH_NoDLC_xHyL_sigma,yerr=UH_NoDLC_xHyL_sigma_err,fmt="o")
NoDLC_xHyL_sigma, NoDLC_xHyL_sigma_err = stripROtools.fit_horizontal(UH_NoDLC_Vmesh,UH_NoDLC_xHyL_sigma,UH_NoDLC_xHyL_sigma_err)
print("NoDLC xHyL sigma = ", NoDLC_xHyL_sigma)
ax4.axhline(NoDLC_xHyL_sigma,color='orange')


for ax in fig.get_axes():
    ax.set(xlabel='Mesh voltage [V]', ylabel='$\sigma$ [ns]')

for ax in fig.get_axes():
    ax.label_outer()

fig.subplots_adjust(wspace=0, hspace=0)
# Out:
# DLC xLyH sigma =  14.218004317140263
# NoDLC xLyH sigma =  14.585845350986046
# DLC xHyH sigma =  13.405970754842297
# NoDLC xHyH sigma =  15.066974101662112
# DLC xLyL sigma =  11.31345346056671
# NoDLC xLyL sigma =  14.028540354046307
# DLC xHyL sigma =  13.092249697184801
# NoDLC xHyL sigma =  14.281109122195478
